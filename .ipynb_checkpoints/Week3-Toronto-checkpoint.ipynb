# %% [markdown]
# <h1 align="center"><font size="5">Segmenting and Clustering Neighborhoods in Toronto</font></h1>

# %% [markdown]
# <a id='ToC'></a>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <h1> Table of Contents</h1>  <br>
#
# 1. <a href='#FirstSection'>Scrape Canadian Postal Code</a> <br>
#
#      1.1. <a href='#11'>BeautifulSoup</a> <br>
#
#      1.2. <a href='#12'>Preprocessing</a> <br>
#
#      1.3. <a href='#13'>Clean DataFrame</a>  <br>
#
# 2. <a href='#SecondSection'>Obtain the Latitude and Longitude coordinates</a> <br>
#
#      2.1. <a href='#21'>Using package - did not work</a> <br>
#
#      2.2. <a href='#22'>Using csv</a> <br>
#
#      2.3. <a href='#23'>Latitude Longitude DataFrame - Final</a>
# <!--3. [Explore and cluster the Toronto Neighborhood](#ThirdSection)
#      3.1. [Following the NY Cluster lab](#31)
#      3.2. [Subsetting to East, Central, Downtown, and West Toronto](#32)
#      3.3. [Decoupling Neighborhood](#33)
#      3.4. [Map of East, Central, Downtown, and West Toronto Neighborhood](#34)
#      3.5. [FourSquare API](#35)
#      3.6. [Preprocessing Neighborhood](#36)
#      3.7. [K-Means Clustering](#37)
#      3.8. [Cluster Map](#38)
#      3.9. [Examine Cluster](#39)  -->
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success" style="margin-top: 20px">
#
# <a id='FirstSection'> <H1> First Assignment - Scrape Canadian Postal Code</H1></a>
#
#  1.1. <a href='#11'>BeautifulSoup</a> <br>
#
#  1.2. <a href='#12'>Preprocessing</a> <br>
#
#  1.3. <a href='#13'>Clean DataFrame</a>  <br>
#
# </div>

# %% [markdown]
# Let's import a couple dependancies before we start:

# %%
# Segmenting and Clustering Neighborhoods in Toronto
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import json # library to handle JSON files
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

# %% [markdown]
# <a id='11'> BeautifulSoup</H1></a>

# %% [markdown]
# First things first: let's scrape the wikipedia page, using BeautifulSoup package

# %%
from bs4 import BeautifulSoup

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(source,'lxml')

# %%
table = soup.find('table',class_='wikitable sortable')

# %%
# to show the table:
# table.prettify().splitlines()

# %%
# Convert the html into pandas dataframe:
df = pd.read_html(str(table),header=0)[0]

# %% [markdown]
# <a id='12'> Pre-processing</a>
# * The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood

# %%
# rename the column to the one specified by the assignment
df.columns = ['PostalCode','Borough','Neighborhood']

# %%
df.head()
# Out:
#   PostalCode           Borough      Neighborhood
# 0        M1A      Not assigned      Not assigned
# 1        M2A      Not assigned      Not assigned
# 2        M3A        North York         Parkwoods
# 3        M4A        North York  Victoria Village
# 4        M5A  Downtown Toronto      Harbourfront

# %%
# sanity check:
df[df.PostalCode=='M2H']
# Out:
#    PostalCode     Borough       Neighborhood
# 63        M2H  North York  Hillcrest Village

# %% [markdown]
# * Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.

# %%
# remove cells with a borough that is "Not assigned"
df = df[df.Borough!='Not assigned']

# %%
# to check whether all the 'not assigned' has been dropped:
sum(df.Borough=='Not assigned')
# Out:
# 0

# %%
df.shape
# Out:
# (211, 3)

# %% [markdown]
# * More than one neighborhood can exist in one postal code area. For example, in the table on the Wikipedia page, you will notice that M5A is listed twice and has two neighborhoods: Harbourfront and Regent Park. These two rows will be combined into one row with the neighborhoods separated with a comma as shown in row 11 in the above table.

# %%
# split the data frame into: duplicated and unique df. 
duplicated_df = df[df.duplicated(subset='PostalCode',keep=False)].sort_values(by='PostalCode')
duplicated_df.head()
# Out:
#    PostalCode      Borough    Neighborhood
# 11        M1B  Scarborough           Rouge
# 12        M1B  Scarborough         Malvern
# 28        M1C  Scarborough      Rouge Hill
# 29        M1C  Scarborough      Port Union
# 27        M1C  Scarborough  Highland Creek

# %%
duplicated_df.shape
# Out:
# (165, 3)

# %% [markdown]
# Let's also separate the dataframe with unique ```PostalCode```. Once the cleaning up of the duplicated ```PostalCode``` is done, we can then add them back in.

# %%
unique_df = df[~df.duplicated(subset='PostalCode',keep=False)].sort_values(by='PostalCode')

# %%
unique_df.shape
# Out:
# (46, 3)

# %%
unique_df[unique_df.PostalCode=='M2H']
# Out:
#    PostalCode     Borough       Neighborhood
# 63        M2H  North York  Hillcrest Village

# %% [markdown]
# There are 211 rows for the ```df``` which had been separated into:
# * ```duplicated_df``` with 165 rows
# * ```unique_df``` with 46 rows

# %% [markdown]
# Let's clean up the ```duplicated_df``` data frame:

# %%
# grab the first duplicated value using the ~ duplicated below:
cleaned_dup_df = duplicated_df[~duplicated_df.duplicated(subset='PostalCode')]
cleaned_dup_df.head()
# Out:
#     PostalCode      Borough  Neighborhood
# 11         M1B  Scarborough         Rouge
# 28         M1C  Scarborough    Rouge Hill
# 44         M1E  Scarborough     West Hill
# 93         M1K  Scarborough  Kennedy Park
# 107        M1L  Scarborough      Clairlea

# %%
cleaned_dup_df.shape
# Out:
# (57, 3)

# %%
# extracting the neighborhood list from the cleaned_dup_df and grabbing them from the 
# duplicated_df dataframe using groupby and get_group method
neighborhood_list = []
for postal in cleaned_dup_df['PostalCode']:
    neighborhood_list.append(list(duplicated_df.groupby('PostalCode').get_group(postal)['Neighborhood']))

# %%
neighborhood_list[:5]
# Out:
# [['Rouge', 'Malvern'],
#  ['Rouge Hill', 'Port Union', 'Highland Creek'],
#  ['West Hill', 'Morningside', 'Guildwood'],
#  ['Kennedy Park', 'Ionview', 'East Birchmount Park'],
#  ['Clairlea', 'Golden Mile', 'Oakridge']]

# %%
# to flatten the list, use list comprehension trick:
neighborhood_list = [', '.join(i) for i in neighborhood_list]
neighborhood_list[:5]
# Out:
# ['Rouge, Malvern',
#  'Rouge Hill, Port Union, Highland Creek',
#  'West Hill, Morningside, Guildwood',
#  'Kennedy Park, Ionview, East Birchmount Park',
#  'Clairlea, Golden Mile, Oakridge']

# %%
# add a new column into the dataframe to hold the new list of multiple neighborhood in one row
cleaned_dup_df.insert(2,'Neighborhood_dup',neighborhood_list)

# %%
# remove the old neighborhood column:
cleaned_dup_df = cleaned_dup_df.drop('Neighborhood',axis=1)

# %%
# rename the 'Neighborhood_dup' with 'Neighborhood'
cleaned_dup_df.columns = ['PostalCode','Borough','Neighborhood']
cleaned_dup_df.head()
# Out:
#     PostalCode      Borough                                 Neighborhood
# 11         M1B  Scarborough                               Rouge, Malvern
# 28         M1C  Scarborough       Rouge Hill, Port Union, Highland Creek
# 44         M1E  Scarborough            West Hill, Morningside, Guildwood
# 93         M1K  Scarborough  Kennedy Park, Ionview, East Birchmount Park
# 107        M1L  Scarborough              Clairlea, Golden Mile, Oakridge

# %%
# combine the unique_df and cleaned_dup_df with concat function:
cleaned_df = pd.concat([cleaned_dup_df,unique_df])

# %%
# sort the value and reset the old index to the new index
cleaned_df.sort_values(by='PostalCode')
cleaned_df = cleaned_df.reset_index(drop=True)

# %%
# For sanity check:
cleaned_df[cleaned_df.PostalCode=='M5A']
# Out:
#    PostalCode           Borough               Neighborhood
# 24        M5A  Downtown Toronto  Harbourfront, Regent Park

# %% [markdown]
# * If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough. So for the 9th cell in the table on the Wikipedia page, the value of the Borough and the Neighborhood columns will be Queen's Park.

# %%
# figured out where the "Not assigned" row in the new cleaned_df located
cleaned_df[cleaned_df.Neighborhood=='Not assigned']
# Out:
#    PostalCode       Borough  Neighborhood
# 95        M7A  Queen's Park  Not assigned

# %%
# rename the neighborhood into "Queen's Park"
cleaned_df.loc[95,'Neighborhood'] = "Queen's Park"

# %%
# For sanity check: compare it with the list of postal code given from this assignment
cleaned_df[cleaned_df['PostalCode'].isin(['M5G','M2H','M4B','M1J','M4G','M4M','M1R','M9V','M9L','M5V','M1B','M7A'])]
# Out:
#    PostalCode           Borough  \
# 0         M1B       Scarborough
# 8         M1R       Scarborough
# 18        M4B         East York
# 35        M5V  Downtown Toronto
# 56        M9V         Etobicoke
# 59        M1J       Scarborough
# 63        M2H        North York
# 76        M4G         East York
# 79        M4M      East Toronto
# 88        M5G  Downtown Toronto
# 95        M7A      Queen's Park
# 99        M9L        North York
#
#                                          Neighborhood
# 0                                      Rouge, Malvern
# 8                                   Maryvale, Wexford
# 18                    Parkview Hill, Woodbine Gardens
# 35  CN Tower, Bathurst Quay, Island airport, Harbo...
# 56  Albion Gardens, Beaumond Heights, Humbergate, ...
# 59                                Scarborough Village
# 63                                  Hillcrest Village
# 76                                            Leaside
# 79                                    Studio District
# 88                                 Central Bay Street
# 95                                       Queen's Park
# 99                                      Humber Summit

# %% [markdown]
# <a id='13'> Clean DataFrame</a>
# * Clean your Notebook and add Markdown cells to explain your work and any assumptions you are making.

# %%
# Here is the finished dataframe:
cleaned_df
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1K       Scarborough
# 4          M1L       Scarborough
# 5          M1M       Scarborough
# 6          M1N       Scarborough
# 7          M1P       Scarborough
# 8          M1R       Scarborough
# 9          M1T       Scarborough
# 10         M1V       Scarborough
# 11         M2J        North York
# 12         M2L        North York
# 13         M2M        North York
# 14         M3C        North York
# 15         M3H        North York
# 16         M3J        North York
# 17         M3K        North York
# 18         M4B         East York
# 19         M4K      East Toronto
# 20         M4L      East Toronto
# 21         M4T   Central Toronto
# 22         M4V   Central Toronto
# 23         M4X  Downtown Toronto
# 24         M5A  Downtown Toronto
# 25         M5B  Downtown Toronto
# 26         M5H  Downtown Toronto
# 27         M5J  Downtown Toronto
# 28         M5K  Downtown Toronto
# 29         M5L  Downtown Toronto
# ..         ...               ...
# 73         M4A        North York
# 74         M4C         East York
# 75         M4E      East Toronto
# 76         M4G         East York
# 77         M4H         East York
# 78         M4J         East York
# 79         M4M      East Toronto
# 80         M4N   Central Toronto
# 81         M4P   Central Toronto
# 82         M4R   Central Toronto
# 83         M4S   Central Toronto
# 84         M4W  Downtown Toronto
# 85         M4Y  Downtown Toronto
# 86         M5C  Downtown Toronto
# 87         M5E  Downtown Toronto
# 88         M5G  Downtown Toronto
# 89         M5N   Central Toronto
# 90         M5W  Downtown Toronto
# 91         M6B        North York
# 92         M6C              York
# 93         M6E              York
# 94         M6G  Downtown Toronto
# 95         M7A      Queen's Park
# 96         M7R       Mississauga
# 97         M7Y      East Toronto
# 98         M9A         Etobicoke
# 99         M9L        North York
# 100        M9N              York
# 101        M9P         Etobicoke
# 102        M9W         Etobicoke
#
#                                           Neighborhood
# 0                                       Rouge, Malvern
# 1               Rouge Hill, Port Union, Highland Creek
# 2                    West Hill, Morningside, Guildwood
# 3          Kennedy Park, Ionview, East Birchmount Park
# 4                      Clairlea, Golden Mile, Oakridge
# 5      Cliffcrest, Cliffside, Scarborough Village West
# 6                          Birch Cliff, Cliffside West
# 7    Wexford Heights, Dorset Park, Scarborough Town...
# 8                                    Maryvale, Wexford
# 9              Clarks Corners, Sullivan, Tam O'Shanter
# 10   Steeles East, Milliken, Agincourt North, L'Amo...
# 11                        Oriole, Fairview, Henry Farm
# 12                            York Mills, Silver Hills
# 13                             Newtonbrook, Willowdale
# 14                    Don Mills South, Flemingdon Park
# 15     Wilson Heights, Downsview North, Bathurst Manor
# 16                     Northwood Park, York University
# 17                         CFB Toronto, Downsview East
# 18                     Parkview Hill, Woodbine Gardens
# 19                        The Danforth West, Riverdale
# 20                      India Bazaar, The Beaches West
# 21                         Summerhill East, Moore Park
# 22   Rathnelly, Deer Park, South Hill, Summerhill W...
# 23                         Cabbagetown, St. James Town
# 24                           Harbourfront, Regent Park
# 25                            Ryerson, Garden District
# 26                            King, Adelaide, Richmond
# 27   Harbourfront East, Toronto Islands, Union Station
# 28            Toronto Dominion Centre, Design Exchange
# 29                      Victoria Hotel, Commerce Court
# ..                                                 ...
# 73                                    Victoria Village
# 74                                    Woodbine Heights
# 75                                         The Beaches
# 76                                             Leaside
# 77                                    Thorncliffe Park
# 78                                        East Toronto
# 79                                     Studio District
# 80                                       Lawrence Park
# 81                                    Davisville North
# 82                                  North Toronto West
# 83                                          Davisville
# 84                                            Rosedale
# 85                                Church and Wellesley
# 86                                      St. James Town
# 87                                         Berczy Park
# 88                                  Central Bay Street
# 89                                            Roselawn
# 90                     Stn A PO Boxes 25 The Esplanade
# 91                                           Glencairn
# 92                                  Humewood-Cedarvale
# 93                                 Caledonia-Fairbanks
# 94                                            Christie
# 95                                        Queen's Park
# 96               Canada Post Gateway Processing Centre
# 97   Business Reply Mail Processing Centre 969 Eastern
# 98                                    Islington Avenue
# 99                                       Humber Summit
# 100                                             Weston
# 101                                          Westmount
# 102                                          Northwest
#
# [103 rows x 3 columns]

# %% [markdown]
# * In the last cell of your notebook, use the .shape method to print the number of rows of your dataframe.

# %%
cleaned_df.shape
# Out:
# (103, 3)

# %% [markdown]
# <div class="alert alert-block alert-success" style="margin-top: 20px">
#
# <a id='SecondSection'> <H1> Second Assignment - Obtain the Latitude and Longitude coordinates </H1></a>
#
#    2.1. <a href='#21'>Using package - did not work</a> <br>
#
#    2.2. <a href='#22'>Using csv</a> <br>
#
#    2.3. <a href='#23'>Latitude Longitude DataFrame - Final</a>   <br>
#
# [Back to the top](#ToC)
#
# </div>

# %%
## this is how I would have used the geocoder
## unfortunately, the code did not work 
#import geocoder # import geocoder
#lat_lng = []
#for postal_code in cleaned_df['PostalCode']:
#    lat_lng_coords = None
#    # loop until you get the coordinates
#    while(lat_lng_coords is None):
#        g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
#        lat_lng_coords = g.latlng
#    lat_lng.append(lat_lng_coords)

# %% [markdown]
# <a id='21'>Using package - did not work</a>

# %%
# Instead, I am going to use the pypostalcode package:
# example using'M5G':
from pypostalcode import PostalCodeDatabase
pcdb = PostalCodeDatabase()
pc = 'M5G'
location = pcdb[pc]
print("latitude for M5G:",location.latitude)
print("longitude for M5G:",location.longitude)
# Out:
# latitude for M5G: 43.6519
# longitude for M5G: -79.3874

# %%
# let's create a for loop and getting all the data into one:
pcdb = PostalCodeDatabase()
lat_ca = []
long_ca = []
for postal_code in cleaned_df['PostalCode']:
    try:
        location = pcdb[postal_code]
    except:
        location.latitude = np.nan
        location.longitude = np.nan
    lat_ca.append(location.latitude)
    long_ca.append(location.longitude)
# let's insert the latitude column into the cleaned_df:
cleaned_df.insert(3,'Latitude',lat_ca)
# let's insert the latitude column into the cleaned_df:
cleaned_df.insert(4,'Longitude',long_ca)
# Check one row that is missing:
cleaned_df[cleaned_df['Latitude'].isnull()]
# Out:
#    PostalCode      Borough                           Neighborhood  Latitude  \
# 96        M7R  Mississauga  Canada Post Gateway Processing Centre       NaN
#
#     Longitude
# 96        NaN

# %%
# to get the value, we will use the csv file given by the IBM coursera course:
downloaded_df = pd.read_csv('Geospatial_Coordinates.csv')
downloaded_df.head()
# let's make sure that the column name is the same as what we had in cleaned_df:
downloaded_df.columns = ['PostalCode','Latitude','Longitude']
# from the downloaded_df:
# downloaded_df[downloaded_df['Postal Code']=='M7R']
# let's replace the NaN value for M7R:
cleaned_df.loc[cleaned_df['Latitude'].isnull(),'Latitude'] = float(downloaded_df[downloaded_df['PostalCode']=='M7R']['Latitude'])
cleaned_df.loc[cleaned_df['Longitude'].isnull(),'Longitude'] = float(downloaded_df[downloaded_df['PostalCode']=='M7R']['Longitude'])
cleaned_df.loc[cleaned_df.PostalCode=='M7R']
# Out:
#    PostalCode      Borough                           Neighborhood   Latitude  \
# 96        M7R  Mississauga  Canada Post Gateway Processing Centre  43.636966
#
#     Longitude
# 96 -79.615819

# %%
# For sanity check: compare it with the list of postal code given from this assignment
cleaned_df[cleaned_df['PostalCode'].isin(['M5G','M2H','M4B','M1J','M4G','M4M','M1R','M9V','M9L','M5V','M1B','M5A'])]
# Out:
#    PostalCode           Borough  \
# 0         M1B       Scarborough
# 8         M1R       Scarborough
# 18        M4B         East York
# 24        M5A  Downtown Toronto
# 35        M5V  Downtown Toronto
# 56        M9V         Etobicoke
# 59        M1J       Scarborough
# 63        M2H        North York
# 76        M4G         East York
# 79        M4M      East Toronto
# 88        M5G  Downtown Toronto
# 99        M9L        North York
#
#                                          Neighborhood  Latitude  Longitude
# 0                                      Rouge, Malvern   43.7976   -79.2270
# 8                                   Maryvale, Wexford   43.7293   -79.3038
# 18                    Parkview Hill, Woodbine Gardens   43.6979   -79.2986
# 24                          Harbourfront, Regent Park   43.6369   -79.3505
# 35  CN Tower, Bathurst Quay, Island airport, Harbo...   43.6525   -79.3686
# 56  Albion Gardens, Beaumond Heights, Humbergate, ...   43.7300   -79.5542
# 59                                Scarborough Village   43.7315   -79.2460
# 63                                  Hillcrest Village   43.7895   -79.3735
# 76                                            Leaside   43.6918   -79.3708
# 79                                    Studio District   43.6505   -79.3369
# 88                                 Central Bay Street   43.6519   -79.3874
# 99                                      Humber Summit   43.7494   -79.5614

# %% [markdown]
# <a id='22'> Using csv</a>
# The value doesn't exactly aligned with the data provided by the coursera assignment, so I will instead use the downloaded_df value:

# %%
# let's create a new dataframe and drop the Latitude and Longitude columns from the dataframe
cleaned_df2 = cleaned_df.copy()
cleaned_df2.drop(['Latitude','Longitude'],axis=1,inplace=True)
cleaned_df2.head()
# Out:
#   PostalCode      Borough                                 Neighborhood
# 0        M1B  Scarborough                               Rouge, Malvern
# 1        M1C  Scarborough       Rouge Hill, Port Union, Highland Creek
# 2        M1E  Scarborough            West Hill, Morningside, Guildwood
# 3        M1K  Scarborough  Kennedy Park, Ionview, East Birchmount Park
# 4        M1L  Scarborough              Clairlea, Golden Mile, Oakridge

# %%
# merge cleaned_df2 with downloaded_df to add latitude/longitude for each PostalCode
cleaned_df2 = cleaned_df2.join(downloaded_df.set_index('PostalCode'), on='PostalCode')

# %% [markdown]
# <a id='23'>Latitude Longitude DataFrame - Final</a>

# %%
# For sanity check: compare it with the list of postal code given from this assignment
cleaned_df2[cleaned_df2['PostalCode'].isin(['M5G','M2H','M4B','M1J','M4G','M4M','M1R','M9V','M9L','M5V','M1B','M5A'])]
# Out:
#    PostalCode           Borough  \
# 0         M1B       Scarborough
# 8         M1R       Scarborough
# 18        M4B         East York
# 24        M5A  Downtown Toronto
# 35        M5V  Downtown Toronto
# 56        M9V         Etobicoke
# 59        M1J       Scarborough
# 63        M2H        North York
# 76        M4G         East York
# 79        M4M      East Toronto
# 88        M5G  Downtown Toronto
# 99        M9L        North York
#
#                                          Neighborhood   Latitude  Longitude
# 0                                      Rouge, Malvern  43.806686 -79.194353
# 8                                   Maryvale, Wexford  43.750072 -79.295849
# 18                    Parkview Hill, Woodbine Gardens  43.706397 -79.309937
# 24                          Harbourfront, Regent Park  43.654260 -79.360636
# 35  CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 56  Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 59                                Scarborough Village  43.744734 -79.239476
# 63                                  Hillcrest Village  43.803762 -79.363452
# 76                                            Leaside  43.709060 -79.363452
# 79                                    Studio District  43.659526 -79.340923
# 88                                 Central Bay Street  43.657952 -79.387383
# 99                                      Humber Summit  43.756303 -79.565963

# %% [markdown]
# This value is the same as the one given from the coursera assignment.

# %%
# To show the whole value:
cleaned_df2
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1K       Scarborough
# 4          M1L       Scarborough
# 5          M1M       Scarborough
# 6          M1N       Scarborough
# 7          M1P       Scarborough
# 8          M1R       Scarborough
# 9          M1T       Scarborough
# 10         M1V       Scarborough
# 11         M2J        North York
# 12         M2L        North York
# 13         M2M        North York
# 14         M3C        North York
# 15         M3H        North York
# 16         M3J        North York
# 17         M3K        North York
# 18         M4B         East York
# 19         M4K      East Toronto
# 20         M4L      East Toronto
# 21         M4T   Central Toronto
# 22         M4V   Central Toronto
# 23         M4X  Downtown Toronto
# 24         M5A  Downtown Toronto
# 25         M5B  Downtown Toronto
# 26         M5H  Downtown Toronto
# 27         M5J  Downtown Toronto
# 28         M5K  Downtown Toronto
# 29         M5L  Downtown Toronto
# ..         ...               ...
# 73         M4A        North York
# 74         M4C         East York
# 75         M4E      East Toronto
# 76         M4G         East York
# 77         M4H         East York
# 78         M4J         East York
# 79         M4M      East Toronto
# 80         M4N   Central Toronto
# 81         M4P   Central Toronto
# 82         M4R   Central Toronto
# 83         M4S   Central Toronto
# 84         M4W  Downtown Toronto
# 85         M4Y  Downtown Toronto
# 86         M5C  Downtown Toronto
# 87         M5E  Downtown Toronto
# 88         M5G  Downtown Toronto
# 89         M5N   Central Toronto
# 90         M5W  Downtown Toronto
# 91         M6B        North York
# 92         M6C              York
# 93         M6E              York
# 94         M6G  Downtown Toronto
# 95         M7A      Queen's Park
# 96         M7R       Mississauga
# 97         M7Y      East Toronto
# 98         M9A         Etobicoke
# 99         M9L        North York
# 100        M9N              York
# 101        M9P         Etobicoke
# 102        M9W         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                       Rouge, Malvern  43.806686 -79.194353
# 1               Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 2                    West Hill, Morningside, Guildwood  43.763573 -79.188711
# 3          Kennedy Park, Ionview, East Birchmount Park  43.727929 -79.262029
# 4                      Clairlea, Golden Mile, Oakridge  43.711112 -79.284577
# 5      Cliffcrest, Cliffside, Scarborough Village West  43.716316 -79.239476
# 6                          Birch Cliff, Cliffside West  43.692657 -79.264848
# 7    Wexford Heights, Dorset Park, Scarborough Town...  43.757410 -79.273304
# 8                                    Maryvale, Wexford  43.750072 -79.295849
# 9              Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 10   Steeles East, Milliken, Agincourt North, L'Amo...  43.815252 -79.284577
# 11                        Oriole, Fairview, Henry Farm  43.778517 -79.346556
# 12                            York Mills, Silver Hills  43.757490 -79.374714
# 13                             Newtonbrook, Willowdale  43.789053 -79.408493
# 14                    Don Mills South, Flemingdon Park  43.725900 -79.340923
# 15     Wilson Heights, Downsview North, Bathurst Manor  43.754328 -79.442259
# 16                     Northwood Park, York University  43.767980 -79.487262
# 17                         CFB Toronto, Downsview East  43.737473 -79.464763
# 18                     Parkview Hill, Woodbine Gardens  43.706397 -79.309937
# 19                        The Danforth West, Riverdale  43.679557 -79.352188
# 20                      India Bazaar, The Beaches West  43.668999 -79.315572
# 21                         Summerhill East, Moore Park  43.689574 -79.383160
# 22   Rathnelly, Deer Park, South Hill, Summerhill W...  43.686412 -79.400049
# 23                         Cabbagetown, St. James Town  43.667967 -79.367675
# 24                           Harbourfront, Regent Park  43.654260 -79.360636
# 25                            Ryerson, Garden District  43.657162 -79.378937
# 26                            King, Adelaide, Richmond  43.650571 -79.384568
# 27   Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 28            Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 29                      Victoria Hotel, Commerce Court  43.648198 -79.379817
# ..                                                 ...        ...        ...
# 73                                    Victoria Village  43.725882 -79.315572
# 74                                    Woodbine Heights  43.695344 -79.318389
# 75                                         The Beaches  43.676357 -79.293031
# 76                                             Leaside  43.709060 -79.363452
# 77                                    Thorncliffe Park  43.705369 -79.349372
# 78                                        East Toronto  43.685347 -79.338106
# 79                                     Studio District  43.659526 -79.340923
# 80                                       Lawrence Park  43.728020 -79.388790
# 81                                    Davisville North  43.712751 -79.390197
# 82                                  North Toronto West  43.715383 -79.405678
# 83                                          Davisville  43.704324 -79.388790
# 84                                            Rosedale  43.679563 -79.377529
# 85                                Church and Wellesley  43.665860 -79.383160
# 86                                      St. James Town  43.651494 -79.375418
# 87                                         Berczy Park  43.644771 -79.373306
# 88                                  Central Bay Street  43.657952 -79.387383
# 89                                            Roselawn  43.711695 -79.416936
# 90                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 91                                           Glencairn  43.709577 -79.445073
# 92                                  Humewood-Cedarvale  43.693781 -79.428191
# 93                                 Caledonia-Fairbanks  43.689026 -79.453512
# 94                                            Christie  43.669542 -79.422564
# 95                                        Queen's Park  43.662301 -79.389494
# 96               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 97   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 98                                    Islington Avenue  43.667856 -79.532242
# 99                                       Humber Summit  43.756303 -79.565963
# 100                                             Weston  43.706876 -79.518188
# 101                                          Westmount  43.696319 -79.532242
# 102                                          Northwest  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %% [markdown]
# Let's save the `cleaned_df2` DataFrame so that I can use it for the third assignment.

# %%
cleaned_df2.to_csv('toronto_lat_long.csv',index=False)
